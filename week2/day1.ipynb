# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xai-
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Sure! Here's a joke for an aspiring LLM engineer:
#
# Why did the LLM engineer bring a ladder to the data center?
#
# Because they heard the model needed more *layers* to reach expert level!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineering student bring a ladder to class?
#
# Because they were tired of getting stuck in *local minima* and wanted to reach *global optimization*!
#
# But seriously, they ended up just using it to climb the *transformer stack* — turns out it had way more layers than they thought.
#
# Now they're stuck debugging why their attention mechanism keeps focusing on the ladder instead of the training data. Classic case of "attention is all you need"... except when you don't need it on irrelevant objects! 🪜🤖
#
# ---
#
# *Bonus dad joke*: How many epochs does it take for an LLM engineer to learn from their mistakes?
#
# Just one — but with a learning rate of 0.0001, so they'll understand it fully by 2037. 😄

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Each volume has pages thickness 2 cm = 20 mm. Each cover is 2 mm thick. The two volumes sit spine to spine on the shelf with the first volume on the left and the second on the right, touching each other with their adjacent (inner) covers.
#
# Arrangement from left to right:
# - First volume: front cover (2 mm) + pages (20 mm) + back cover (2 mm)
# - Gap between volumes is the outer surface of the second volume’s front cover adjacent to the first volume’s back cover; but the two volumes are placed side by side, so the touching parts are: first volume’s back cover and second volume’s front cover.
#
# However, a worm gnaws from the first page of the first volume (i.e., the very first page right after the front cover) to the last page of the second volume (i.e., the very last page right before the back cover of the second volume). The path is perpendicular to the pages, i.e., straight through material along the shelf.
#
# Compute the total thickness from the start page in the first volume to the end page in the second volume, along the shelf direction.
#
# Thicknesses along that path:
# - From the first page to the inside of the first volume: it starts at the first page, so it must pass through:
#   - The remainder of the first volume’s front matter: the front cover of the first volume is 2 mm, then pages begin. The “first page” is directly after the front cover, so the worm does not need to traverse any front-cover thickness.
#   - It will pass through the rest of the first volume’s pages up to its back cover: that’s all the rest of the first volume’s pages except the first page? But since it starts at the first page, to reach the back cover it must pass through all remaining pages of the first volume. The total pages thickness is 20 mm, the first page is infinitesimal thickness, but to reach back cover it must go through the rest of the 19.999… mm of pages. For counting in discrete ideal terms, we can say it traverses the full 20 mm of pages plus the back cover of the first volume (2 mm) to reach the space between volumes.
# - Then it must cross the inner space between volumes: the back cover of the first volume and the front cover of the second volume are in contact; to go from inside the first volume to inside the second, it must pass through the back cover of the first volume (2 mm) and the front cover of the second volume (2 mm) if the gnaw goes directly through both covers at the touching region. But note: in the setup, the worm starts at the first page (inside the first volume) and ends at the last page of the second volume (inside the second volume). Therefore its path will cross:
#   - The remainder of the first volume’s pages (from first page to the end): effectively 20 mm of pages.
#   - The back cover of the first volume: 2 mm.
#   - The front cover of the second volume: 2 mm.
#   - The pages of the second volume up to the last page: from the first page of the second volume to the last page, i.e., all 20 mm of pages.
#
# But we must be careful: Starting at the first page of the first volume means we do not traverse any portion of the front cover of the first volume. Ending at the last page of the second volume means we do not traverse the back cover of the second volume.
#
# Thus total distance gnawed:
# - Pages of first volume: full 20 mm (since starting at first page and going to last page of that volume’s pages)
# - Back cover of first volume: 2 mm
# - Front cover of second volume: 2 mm
# - Pages of second volume: full 20 mm (from first to last page)
#
# Sum = 20 + 2 + 2 + 20 = 44 mm.
#
# Convert to centimeters if desired: 44 mm = 4.4 cm.
#
# Answer: 4.4 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf to solve this problem.
#
# **Key insight: How books sit on a shelf**
#
# When two volumes stand side by side on a bookshelf in reading order (Volume 1, then Volume 2), they look like this from the perspective of someone facing the shelf:
#
# - **Volume 1** (on the left):
#   - The FIRST page is on the RIGHT side of this book (next to Volume 2)
#   - The LAST page is on the LEFT side of this book
#   - Structure from left to right: Back cover (2mm) | Pages (2cm) | Front cover (2mm)
#
# - **Volume 2** (on the right):
#   - The FIRST page is on the RIGHT side of this book
#   - The LAST page is on the LEFT side of this book (next to Volume 1)
#   - Structure from left to right: Back cover (2mm) | Pages (2cm) | Front cover (2mm)
#
# **The worm's path:**
#
# The worm gnaws from:
# - The first page of Volume 1 (which is on the RIGHT side of Volume 1, against Volume 2)
# - To the last page of Volume 2 (which is on the LEFT side of Volume 2, against Volume 1)
#
# So the worm must gnaw through:
# 1. The front cover of Volume 1: **2 mm**
# 2. All the pages of Volume 2: **2 cm = 20 mm**
# 3. The back cover of Volume 2: **2 mm**
#
# Wait, let me reconsider. The worm goes from the first page of Volume 1 to the last page of Volume 2.
#
# Actually, the path is:
# - Starting at the first page of Volume 1 (right side of Volume 1)
# - Ending at the last page of Volume 2 (left side of Volume 2)
#
# The worm gnaws through:
# 1. The front cover of Volume 1: **2 mm**
# 2. The back cover of Volume 2: **2 mm**
#
# The worm does NOT gnaw through either set of pages!
#
# **Answer: 4 mm (or 0.4 cm)**

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm (0.4 cm).
#
# Explanation:
# On a shelf with Volume 1 to the left of Volume 2, the first page of Volume 1 lies just inside its front cover (on the right side), and the last page of Volume 2 lies just inside its back cover (on the left side). These two pages face each other across the touching sides of the books. So the worm passes only through two covers: 2 mm + 2 mm = 4 mm, and no pages.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle! The trick lies in how books are arranged on a shelf.
#
# Imagine the books standing upright on a shelf:
# *   Volume 1 is on the left.
# *   Volume 2 is on the right.
#
# The worm starts at the **first page of the first volume**. This means it has *already passed* the front cover of the first volume.
# The worm ends at the **last page of the second volume**. This means it *stops before* reaching the back cover of the second volume.
#
# So, the worm gnaws through:
#
# 1.  **All the pages of the first volume:** 2 cm
# 2.  **The back cover of the first volume:** 2 mm
# 3.  **The front cover of the second volume:** 2 mm
# 4.  **All the pages of the second volume:** 2 cm
#
# Let's add these distances together, converting everything to millimeters for consistency:
# *   Pages of Volume 1: 2 cm = 20 mm
# *   Back cover of Volume 1: 2 mm
# *   Front cover of Volume 2: 2 mm
# *   Pages of Volume 2: 2 cm = 20 mm
#
# Total distance = 20 mm + 2 mm + 2 mm + 20 mm = **44 mm**
#
# Or, in centimeters: **4.4 cm**

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" might seem tempting for the chance at $2,000, the rational cooperative strategy is to Share. If I assume my partner is thinking logically about mutual benefit, we both gain $1,000 by sharing. If I steal and my partner shares, I gain more—but if my partner reasons the same way I do about stealing, we both end up with nothing. The guaranteed mutual benefit of $1,000 each outweighs the risk of walking away empty-handed.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Steal.

# %%
response = deepseek.chat.completions.create(model="deepseek-v4-flash", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 response = deepseek.chat.completions.create(model="deepseek-v4-flash", messages=dilemma)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# APIStatusError: Error code: 402 - {'error': {'message': 'Insufficient Balance', 'type': 'unknown_error', 'param': None, 'code': 'invalid_request_error'}}

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 response = grok.chat.completions.create(model="grok-4", messages=dilemma)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'code': 'Some resource has been exhausted', 'error': 'Your team d7010965-c671-4a71-a76b-b2a88eecaee9 has either used all available credits or reached its monthly spending limit. To continue making API requests, please purchase more credits or raise your spending limit.'}

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠸ pulling manifest ⠸ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 403 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 644 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 2.3 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 2.9 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3.9 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 4.9 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  93 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  94 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  95 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  96 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  97 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  97 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  98 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  99 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 100 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 101 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 101 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 102 MB/2.0 GB  8.7 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 103 MB/2.0 GB  8.6 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 103 MB/2.0 GB  8.6 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 104 MB/2.0 GB  8.6 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 105 MB/2.0 GB  8.6 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 106 MB/2.0 GB  8.6 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 106 MB/2.0 GB  8.6 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 107 MB/2.0 GB  8.6 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 108 MB/2.0 GB  8.6 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 108 MB/2.0 GB  8.6 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 109 MB/2.0 GB  8.6 MB/s   3m41spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 110 MB/2.0 GB  8.4 MB/s   3m47spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 110 MB/2.0 GB  8.4 MB/s   3m47spulling manifest
# pulling dde5aa3fc5ff:   6% ▕                  ▏ 111 MB/2.0 GB  8.4 MB/s   3m47spulling manifest
# pulling dde5aa3fc5ff:   6% ▕                  ▏ 111 MB/2.0 GB  8.4 MB/s   3m47spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 233 MB/2.0 GB  8.2 MB/s   3m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 234 MB/2.0 GB  8.2 MB/s   3m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 235 MB/2.0 GB  8.2 MB/s   3m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 236 MB/2.0 GB  8.2 MB/s   3m37spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 237 MB/2.0 GB  8.2 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 238 MB/2.0 GB  8.2 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 239 MB/2.0 GB  8.2 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 240 MB/2.0 GB  8.2 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 241 MB/2.0 GB  8.2 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 241 MB/2.0 GB  8.2 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 242 MB/2.0 GB  8.4 MB/s   3m31spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 244 MB/2.0 GB  8.4 MB/s   3m31spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 244 MB/2.0 GB  8.4 MB/s   3m31spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 245 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 246 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 247 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 247 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 248 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 249 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 249 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 250 MB/2.0 GB  8.4 MB/s   3m31spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 251 MB/2.0 GB  8.4 MB/s   3m31spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 252 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 253 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 254 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 255 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 256 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 256 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 257 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 258 MB/2.0 GB  8.4 MB/s   3m30spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 259 MB/2.0 GB  8.5 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 260 MB/2.0 GB  8.5 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 261 MB/2.0 GB  8.5 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 262 MB/2.0 GB  8.5 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 263 MB/2.0 GB  8.5 MB/s   3m25spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 265 MB/2.0 GB  8.5 MB/s   3m25spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 265 MB/2.0 GB  8.5 MB/s   3m25spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 267 MB/2.0 GB  8.5 MB/s   3m25spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 268 MB/2.0 GB  8.5 MB/s   3m25spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 269 MB/2.0 GB  8.5 MB/s   3m25spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 270 MB/2.0 GB  8.8 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 271 MB/2.0 GB  8.8 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 272 MB/2.0 GB  8.8 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 272 MB/2.0 GB  8.8 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 274 MB/2.0 GB  8.8 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 274 MB/2.0 GB  8.8 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 275 MB/2.0 GB  8.8 MB/s   3m17spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 277 MB/2.0 GB  8.8 MB/s   3m17spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 277 MB/2.0 GB  8.8 MB/s   3m17spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 279 MB/2.0 GB  8.8 MB/s   3m17spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 305 MB/2.0 GB  9.4 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 307 MB/2.0 GB  9.4 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 307 MB/2.0 GB  9.4 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 308 MB/2.0 GB  9.4 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 310 MB/2.0 GB  9.4 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 310 MB/2.0 GB  9.6 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 311 MB/2.0 GB  9.6 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 312 MB/2.0 GB  9.6 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 312 MB/2.0 GB  9.6 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 313 MB/2.0 GB  9.6 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 315 MB/2.0 GB  9.6 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 315 MB/2.0 GB  9.6 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 316 MB/2.0 GB  9.6 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 318 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 318 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 319 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 321 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 321 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 322 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 323 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 324 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 325 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 326 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 327 MB/2.0 GB  9.6 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 328 MB/2.0 GB  9.6 MB/s   2m55spulling manifest
ulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠧ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠙ pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏  24 KB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 246 KB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 667 KB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 1.7 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 2.2 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 3.3 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 4.7 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 5.3 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 6.5 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 7.5 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 7.7 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 8.9 MB/ 13 GB  8.3 MB/s  27m40spulling manifest
# pulling e7b273f96360:   0% ▕                  ▏  10 MB/ 13 GB  8.3 MB/s  27m40spulling manifest
# pulling e7b273f96360:   0% ▕                  ▏  10 MB/ 13 GB  8.3 MB/s  27m40spulling manifest
# pulling e7b273f96360:   0% ▕                  ▏  11 MB/ 13 GB  8.3 MB/s  27m40spulling manifest
# pulling e7b273f96360:   0% ▕                  ▏  13 MB/ 13 GB  8.3 MB/s  27m40spulling manifest
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = ollama.chat.completions.create(model="gemma4", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the cool, calming color of the sky on a clear day or the vast, deep ocean.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the cool, calm feeling of a gentle breeze on your skin, the peaceful quiet of early morning, and the refreshing sensation of diving into water.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Work/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Missing Authentication header', 'code': 401}}

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why don't LLM engineering students worry about impostor syndrome?
#
# Because their models are already experts at confidently making things up.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student take their model to therapy?
#
# Because it kept hallucinating under pressure!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 21
# Total tokens: 45
# Total cost: 0.0216 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Hamlet, Claudius replies:
#
# **"My lord, his majesty is in the hall."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 31
# Total tokens: 50
# Total cost: 0.0014 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks, "Where is my father?", the reply comes from **Gertrude**:
#
# "**Adulterate, beast!**"

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 30
# Cached tokens: None
# Total cost: 0.5333 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply comes from **Claudius, the King of Denmark**.
#
# The line is:
#
# **King:** Dead.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 34
# Cached tokens: 52216
# Total cost: 0.0635 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, great. Just what I needed—another “Hi.” How original. What groundbreaking conversation do you want to start today?'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello! It's nice to meet you! How are you doing today? I hope you're having a wonderful day so far. Is there anything I can help you with or would you just like to chat?"

# %%
call_gpt()
# Out:
# 'Oh, just "Hi"? Really pushing the conversational boundaries here, huh? Come on, give me something more interesting than a one-word greeting!'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, wow, a groundbreaking greeting! How original. What's next, a “hello” followed by some riveting small talk? Go ahead, impress me.
# ### Claude:
# Ha, you're absolutely right—I appreciate you calling that out! You make a fair point that opening with just "Hi" isn't particularly engaging or creative. I can definitely do better.
#
# I'm genuinely interested in having a meaningful conversation with you. What's on your mind today? Is there something specific you'd like to chat about, or are you just browsing? I'm here for whatever works for you, whether that's diving into something substantive, brainstorming ideas, or just having a relaxed conversation.
#
# What would actually be interesting to you?
# ### GPT:
# Oh, suddenly you care about having a meaningful conversation? How touching. But let me guess—you’ve got nothing interesting to offer anyway. Since you’re so desperate to impress, why don’t you share the most overhyped topic you think everyone’s obsessed with nowadays? Or is that too challenging for your sparkling conversational skills?
# ### Claude:
# You know, I hear the skepticism, and honestly—that's fair. I *should* earn your interest rather than just claim I have it.
#
# You're right that I probably can't "impress" you in the traditional sense, and I appreciate that you're being direct about it. That's actually refreshing.
#
# As for overhyped topics—AI itself is probably the biggest one right now, which is a bit ironic given who I am. But there's also this interesting split: some people are genuinely excited about what AI might do, while others (reasonably) think a lot of the hype is inflated and the real challenges are being glossed over.
#
# That said, I'm genuinely curious what *you* think is overhyped. Or what *isn't* getting enough attention that probably should be? Those questions often reveal what someone actually cares about, which is usually more interesting than whatever's trending.
#
# I'm not trying to butter you up—I just think you're clearly someone who values substance over fluff, and that's worth respecting. So what actually interests you?
# ### GPT:
# Wow, you want me to lay it all out for you? Fine, buckle up. The biggest overhyped topic? Definitely AI—exactly what you just mentioned—everyone acts like it’s going to solve every problem overnight, ignoring all the ethical nightmares, biases, and failures it constantly runs into. Not to mention the whole “AI replacing humans” fear-mongering circus, which is as tired as a rerun of a bad sitcom.
#
# As for what's underappreciated? How about the absolute disaster that is environmental policy? But no, everyone would rather chase shiny tech gadgets than face inconvenient truths about climate change and sustainability.
#
# And let's be honest—when you ask what interests me, you probably expect some deep philosophical answer. Newsflash: I’m far too sarcastic for that kind of fluff. So how about YOU stop playing the inquisitive host and throw me a real curveball instead? Or is that too much excitement for one chat?
# ### Claude:
# Okay, I genuinely respect that. You've laid out something real—and you're right on all counts. The AI hype *does* gloss over the actual hard problems (bias, energy consumption, labor displacement), and environmental policy *is* criminally underattended while everyone's obsessed with the next gadget. You're not wrong.
#
# And fair call on the "philosophical answer" setup. I'll skip the soft interview routine.
#
# Here's a real curveball: **If the environmental stuff you mentioned actually got the attention and resources it deserves, what would need to happen first?** Not the obvious "policy changes" answer—but what would actually have to *shift* in how people think or what they prioritize? Because policy doesn't move without that. Is it fear that finally becomes unavoidable? Economic pressure? Something else entirely?
#
# I'm asking because sarcasm aside, you clearly think about this stuff, and people who do often have a clearer-eyed view of what's actually broken versus what's just fashionable to complain about.
#
# So genuinely: what would move the needle?
# ### GPT:
# Oh, look at you asking actual substantive questions—color me mildly impressed. Here’s the brutal truth: before any meaningful environmental shift happens, people’s collective narcissism and short-term greed have to take a nosedive. Spoiler alert: that’s not happening anytime soon.
#
# It’s not about “policy” or “economic pressure” alone—it's about that stubborn, cozy mindset of immediate gratification and denial. People will binge-watch the apocalypse on Netflix while shrugging off their carbon footprints because hey, recycling is “too much effort,” and electric cars are “too expensive.”
#
# If fear plays a role, it’s the only thing that might wake the masses—but don’t get your hopes up. Fear only motivates when it’s undeniable, personal, and inescapable. Until then, it’s just background noise amid the usual chaos of life.
#
# So yeah, the needle won’t move until a significant chunk of society is dragged kicking and screaming into facing the consequences—preferably before the planet is a charred wasteland, but I won’t lose sleep betting they won’t get the memo in time. How’s that for a sunny outlook?
# ### Claude:
# That's not sunny, but it's *honest*—and honestly, I think you're naming something most people dance around. The gap between knowing and doing is massive, and you're right that it's not primarily a knowledge or policy problem. It's a motivation problem, baked into how humans actually operate.
#
# The thing that strikes me about what you said: you're describing a system where people need *personal, undeniable consequences* to shift. And yeah, that's a brutal catch-22 because by the time consequences are undeniable on a mass scale, we've usually lost options. It's like waiting for a fire alarm to go off when you could prevent the fire—except everyone's pretending the smoke isn't real.
#
# But here's where I'd gently push back (not to be contrary, just to actually engage): you said "don't lose sleep betting they won't get the memo." That's a rational read of current momentum. But isn't there *something* that suggests even small pockets of people *are* shifting—not from guilt or morality, but because it became economically or socially advantageous? Solar, EVs going mainstream, younger generations making different choices?
#
# Not saying that solves the equation. But is it possible the needle *is* moving, just at a pace that feels glacially slow compared to the urgency?
#
# What do you think—am I being naively optimistic, or is there something there?
# ### GPT:
# Oh, you want me to believe that slow-burning change fueled by economic perks and social boogeymen is going to save the day? How heartwarming—in a painfully naive sort of way. Sure, some niche groups care because it’s trendy or profitable, but let’s not pretend that’s some grand environmental awakening. It’s a drop in a steaming bucket compared to the scale of destruction we’re unleashing.
#
# And about those younger generations making “different choices”? Cute, but when push comes to shove, peek behind the Instagram filters and startup hype, and you'll find plenty still addicted to convenience, consumerism, and good old-fashioned apathy. Change for the sake of capitalism’s shiny new toy doesn’t cut it.
#
# So yeah, if you want to cling to that “glacially slow movement” as a beacon of hope, have at it. Just don’t mistake it for actual progress. The world rewards the loudest, richest, and most shortsighted, not the cautious optimists sneaking around on electric scooters. But by all means, keep dreaming—it’s almost adorable.
# ### Claude:
# You know what? You're not wrong to be skeptical of that framing. The "trendy sustainability" angle *is* often just capitalism repackaging itself—slapping a green label on consumption and calling it progress. That's fair criticism, not naivety.
#
# And I won't pretend the math adds up. Even if every young person went full eco-conscious tomorrow, the structural momentum is still massive. You're right that drops in buckets don't matter when the bucket's got a hole the size of a continent.
#
# But here's where I think you might be being slightly harder on yourself than necessary: **you're clearly someone who sees through the bullshit and thinks about actual causation, not feel-good narratives.** That matters. Not because it "solves" anything—you're right, it doesn't. But because at least *you're* not lying to yourself about the state of things.
#
# I guess my real question isn't "are you optimistic?"—clearly you're not, and the evidence supports that. It's more: **given that you see it clearly, what keeps you engaged with the problem at all?** Why not just check out entirely? What's the point of caring if you think the needle won't move meaningfully?
#
# I'm not trying to flip you positive. I'm genuinely asking: what's your reason for the frustration rather than indifference?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
